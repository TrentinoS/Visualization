# %% [markdown]
# <i><h1 align='center' style='color:#f4a261'>Interactive Plot With Pygal</h1></i>

# %%
import pygal

# %%
bar_chart = pygal.Bar()

# %%
def factorial(n):
    if n == 1 or n == 0:
        return 1
    else:
        return n * factorial(n-1)
fact_list = [factorial(i) for i in range(11)]

# %%
from IPython.display import display, HTML
base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %%
bar_chart = pygal.Bar(height=400)
bar_chart.add('Factorial', fact_list)
display(HTML(base_html.format(rendered_chart=bar_chart.render(is_unicode=True))))

bar_chart.render_to_file('Plots/barchart0.svg')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-5ce40dcf-6adf-44e7-a630-c475ca27669c" class="pygal-chart" viewBox="0 0 800 400"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-5ce40dcf-6adf-44e7-a630-c475ca27669c{background-color:rgba(249,249,249,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c path,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c rect,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .graph{fill:rgba(0,0,0,.87)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c text.no_data{fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .title{fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .legends .legend text{fill:rgba(0,0,0,.87)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .line{stroke:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis text.major{fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y .guides:hover .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .line-graph .axis.x .guides:hover .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .stackedline-graph .axis.x .guides:hover .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .ci{stroke:rgba(0,0,0,.87)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .reactive.active,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .ci .reactive.active{stroke-width:1.5}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .series text{fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip .value{font-size:1.5em}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .bound{font-size:.5em}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .color-0,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .text-overlay .color-0 text{fill:black}
# #chart-5ce40dcf-6adf-44e7-a630-c475ca27669c text.no_data{text-anchor:middle}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .guide.line{fill:none}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .centered{text-anchor:middle}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .title{text-anchor:middle}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .legends .legend text{fill-opacity:1}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.x text{text-anchor:middle}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.x:not(.web) text[transform]{text-anchor:start}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y text{text-anchor:end}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y text[transform].backwards{text-anchor:start}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y2 text{text-anchor:start}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y2 text[transform].backwards{text-anchor:end}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .guide.line{stroke-dasharray:4,4}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .major.guide.line{stroke-dasharray:6,6}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .horizontal .axis.y .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .horizontal .axis.y2 .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .vertical .axis.x .guide.line{opacity:0}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .horizontal .axis.always_show .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y .guides:hover .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.y2 .guides:hover .guide.line,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis.x .guides:hover .guide.line{opacity:1}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .axis .guides:hover text{opacity:1}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .nofill{fill:none}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .subtle-fill{fill-opacity:.2}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .dot{stroke-width:1px;fill-opacity:1}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .dot.active{stroke-width:5px}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .dot.negative{fill:transparent}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c text,#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c tspan{stroke:none !important}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .series text.active{opacity:1}#chart-5ce40dcf-6adf-44e7-a630-c475ca27669c .tooltip rect{fil

# %% [markdown]
# ## Import Data

# %%
import pygal
import pandas as pd

# %%
data = pd.read_csv('Data/us-counties.csv')
data.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
data.sample(10)
# Out:
#                date    county          state     fips  cases  deaths
# 662876   2020-10-24    McLean   North Dakota  38055.0    541     9.0
# 825155   2020-12-13  Delaware           Ohio  39041.0   8773    48.0
# 61730    2020-04-15   Lincoln     Washington  53043.0      2     0.0
# 686991   2020-11-01  Humboldt     California   6023.0    571    10.0
# 1186427  2021-04-03     Clark     Washington  53011.0  20385   248.0
# 31923    2020-04-04   Noxubee    Mississippi  28103.0      5     0.0
# 448185   2020-08-19    Harlan       Kentucky  21095.0    264     4.0
# 1183042  2021-04-02  Accomack       Virginia  51001.0   2716    39.0
# 1157282  2021-03-25    Upshur  West Virginia  54097.0   1761    32.0
# 331959   2020-07-14    Talbot        Georgia  13263.0     96     3.0

# %% [markdown]
# ## Bar Chart

# %%
mean_per_state = data.groupby('state')['cases'].mean()

# %%
#Import needed libraries
import pygal
import pandas as pd
#Parse the dataframe
data = pd.read_csv("Data/us-counties.csv") 
#Get the mean number of cases per states
mean_per_state = data.groupby('state')['cases'].mean()
#Draw the bar chart
barChart = pygal.Bar(height=400)
[barChart.add(x[0], x[1]) for x in mean_per_state.items()]
display(HTML(base_html.format(rendered_chart=barChart.render(is_unicode=True))))

barChart.render_to_file('Plots/barchart.svg')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-57415856-d968-4141-a905-4c69a4eb3a42" class="pygal-chart" viewBox="0 0 800 400"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-57415856-d968-4141-a905-4c69a4eb3a42{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-57415856-d968-4141-a905-4c69a4eb3a42 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-57415856-d968-4141-a905-4c69a4eb3a42{background-color:rgba(249,249,249,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 path,#chart-57415856-d968-4141-a905-4c69a4eb3a42 line,#chart-57415856-d968-4141-a905-4c69a4eb3a42 rect,#chart-57415856-d968-4141-a905-4c69a4eb3a42 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .graph{fill:rgba(0,0,0,.87)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 text.no_data{fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .title{fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis .line{stroke:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis text.major{fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis.y .guides:hover .guide.line,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .line-graph .axis.x .guides:hover .guide.line,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .ci{stroke:rgba(0,0,0,.87)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .reactive.active,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .ci .reactive.active{stroke-width:1.5}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .series text{fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .tooltip .value{font-size:1.5em}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .bound{font-size:.5em}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-0,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-1,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-2,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-3,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-4,#chart-57415856-d968-4141-a905-4c69a4eb3a42 .color-4 a:visit ...

# %% [markdown]
# ## Treemap

# %%
sort_by_cases = data.sort_values(by=['cases'],ascending=False).groupby(['state'])['cases'].apply(list)

# %%
top_10_states = sort_by_cases[:10]

# %%
#Import needed libraries
import pygal
import pandas as pd
#Parse the dataframe
data = pd.read_csv("Data/us-counties.csv") 
#Sort states by cases count
sort_by_cases = data.sort_values(by=['cases'],ascending=False).groupby(['state'])['cases'].apply(list)
#Get the top 10 states with the highest number of cases
top_10_states = sort_by_cases[:10]
#Draw the treemap
treemap = pygal.Treemap(height=400)
[treemap.add(x[0], x[1][:10]) for x in top_10_states.items()]
display(HTML(base_html.format(rendered_chart=treemap.render(is_unicode=True))))

treemap.render_to_file('Plots/treemap.svg')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-75b12ba8-125a-42b6-bbf7-06c864d09503" class="pygal-chart" viewBox="0 0 800 400"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-75b12ba8-125a-42b6-bbf7-06c864d09503{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-75b12ba8-125a-42b6-bbf7-06c864d09503{background-color:rgba(249,249,249,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 path,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 line,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 rect,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .graph{fill:rgba(0,0,0,.87)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 text.no_data{fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .title{fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis .line{stroke:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis text.major{fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis.y .guides:hover .guide.line,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .line-graph .axis.x .guides:hover .guide.line,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .ci{stroke:rgba(0,0,0,.87)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .reactive.active,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .ci .reactive.active{stroke-width:1.5}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .series text{fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .tooltip .value{font-size:1.5em}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .bound{font-size:.5em}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-0,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-1,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-2,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-3,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-4,#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .color-4 a:visit ...
# #chart-75b12ba8-125a-42b6-bbf7-06c864d09503 text.no_data{text-anchor:middle}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .guide.line{fill:none}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .centered{text-anchor:middle}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .title{text-anchor:middle}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .legends .legend text{fill-opacity:1}#chart-75b12ba8-125a-42b6-bbf7-06c864d09503 .axis.x text{text-anchor:middle}#chart-75b12ba8-125a-42b6-bbf7-06c864d0950

# %%
#Import needed libraries
import pygal
import pandas as pd
#Parse the dataframe
data = pd.read_csv("Data/us-counties.csv") 
#Get the cases by county for all states
cases_by_county = data.sort_values(by=['cases'],ascending=False).groupby(['state'], axis=0).apply(
    lambda x : [{"value" : l, "label" : c } for l, c in zip(x['cases'], x['county'])])
cases_by_county= cases_by_county[:10]
#Create a new dictionary that contains the cleaned up version of the data
clean_dict = {}
start_dict= cases_by_county.to_dict()
for key in start_dict.keys():
    values = []
    labels = []
    county = []
    for item in start_dict[key]:
        if item['label'] not in labels:
            labels.append(item['label'])
            values.append(item['value'])
        else:
            i = labels.index(item['label'])
            values[i] += item['value']
    
    for l,v in zip(labels, values):
        county.append({'value':v, 'label':l})
    clean_dict[key] = county
#Convert the data to Pandas series to add it to the treemap
new_series = pd.Series(clean_dict)
#Draw the treemap
treemap = pygal.Treemap(height=200)
[treemap.add(x[0], x[1][:10]) for x in new_series.iteritems()]
display(HTML(base_html.format(rendered_chart=treemap.render(is_unicode=True))))

treemap.render_to_file('Plots/treemap1.svg')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-9251108e-649c-4118-ac5c-34fabdb63d23" class="pygal-chart" viewBox="0 0 800 200"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-9251108e-649c-4118-ac5c-34fabdb63d23{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-9251108e-649c-4118-ac5c-34fabdb63d23{background-color:rgba(249,249,249,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 path,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 line,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 rect,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .graph{fill:rgba(0,0,0,.87)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 text.no_data{fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .title{fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis .line{stroke:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis text.major{fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis.y .guides:hover .guide.line,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .line-graph .axis.x .guides:hover .guide.line,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .ci{stroke:rgba(0,0,0,.87)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .reactive.active,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .ci .reactive.active{stroke-width:1.5}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .series text{fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .tooltip .value{font-size:1.5em}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .bound{font-size:.5em}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-0,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-1,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-2,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-3,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-4,#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .color-4 a:visit ...
# #chart-9251108e-649c-4118-ac5c-34fabdb63d23 text.no_data{text-anchor:middle}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .guide.line{fill:none}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .centered{text-anchor:middle}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .title{text-anchor:middle}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .legends .legend text{fill-opacity:1}#chart-9251108e-649c-4118-ac5c-34fabdb63d23 .axis.x text{text-anchor:middle}#chart-9251108e-649c-4118-ac5c-34fabdb63d2

# %% [markdown]
# ## Pie Chart

# %%
#Import needed libraries
import pygal
import pandas as pd
#Parse the dataframe
data = pd.read_csv("Data/us-counties.csv") 
#Get the mean number of cases per states
sort_by_cases = data.sort_values(by=['cases'],ascending=False).groupby(['state'])['cases'].apply(list)
#Draw the bar chart
pi_chart = pygal.Pie(height=400)
#Get the top 10 states
first10 = list(sort_by_cases.items())[:10]
[pi_chart.add(x[0], x[1]) for x in first10]
#display(HTML(base_html.format(rendered_chart=pi_chart.render(is_unicode=True))))

pi_chart.render_to_file('Plots/piechart.svg')

# %% [markdown]
# ## Gauge chart

# %%
#Import needed libraries
import pygal
import pandas as pd

#Parse the dataframe
data = pd.read_csv("Data/us-counties.csv") 

#Get the mean number of cases per states
mean_per_state = data.groupby('state')['cases'].mean()

#The donut shape gauge chart
gauge = pygal.SolidGauge(inner_radius=0.70)
[gauge.add(x[0], [{"value" : x[1] * 100}] ) for x in mean_per_state.head().iteritems()]
display(HTML(base_html.format(rendered_chart=gauge.render(is_unicode=True))))

gauge.render_to_file('Plots/gauge.svg')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><path id="valuePath-163.593.33333333333333" d="M163.500000 24.453333 A68.880000 68.880000 0 1 1 163.499311 24.453333"/><path id="valuePath-490.593.33333333333333" d="M490.500000 24.453333 A68.880000 68.880000 0 1 1 490.499311 24.453333"/><path id="valuePath-163.5280.0" d="M163.500000 211.120000 A68.880000 68.880000 0 1 1 163.499311 211.120000"/><path id="valuePath-490.5280.0" d="M490.500000 211.120000 A68.880000 68.880000 0 1 1 490.499311 211.120000"/><path id="valuePath-163.5466.6666666666667" d="M163.500000 397.786667 A68.880000 68.880000 0 1 1 163.499311 397.786667"/><style type="text/css">#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2{background-color:rgba(249,249,249,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 path,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 line,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 rect,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .graph{fill:rgba(0,0,0,.87)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 text.no_data{fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .title{fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis .line{stroke:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis text.major{fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.y .guides:hover .guide.line,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .line-graph .axis.x .guides:hover .guide.line,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .ci{stroke:rgba(0,0,0,.87)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .reactive.active,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .ci .reactive.active{stroke-width:1.5}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .series text{fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .tooltip .value{font-size:1.5em}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .bound{font-size:.5em}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-0,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-1,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-2,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-3,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-4,#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .color-4 a:visit ...
# #chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 text.no_data{text-anchor:middle}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .guide.line{fill:none}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .centered{text-anchor:middle}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .title{text-anchor:middle}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .legends .legend text{fill-opacity:1}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.x text{text-anchor:middle}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.y text{text-anchor:end}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.y text[transform].backwards{text-anchor:start}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.y2 text{text-anchor:start}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis.y2 text[transform].backwards{text-anchor:end}#chart-8cb2e78a-7ff2-4cb3-8314-ba02ba02bea2 .axis .guide.lin

# %%
#The needle shape gquge chart
gauge = pygal.Gauge(human_readable=True)
[gauge.add(x[0], [{"value" : x[1] * 100}] ) for x in mean_per_state.head().iteritems()]
display(HTML(base_html.format(rendered_chart=gauge.render(is_unicode=True))))

gauge.render_to_file('Plots/gauge1.svg')
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-624ac953-4914-4054-b144-0571efde09cc" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-624ac953-4914-4054-b144-0571efde09cc{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-624ac953-4914-4054-b144-0571efde09cc .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-624ac953-4914-4054-b144-0571efde09cc .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-624ac953-4914-4054-b144-0571efde09cc .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-624ac953-4914-4054-b144-0571efde09cc .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-624ac953-4914-4054-b144-0571efde09cc .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-624ac953-4914-4054-b144-0571efde09cc .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-624ac953-4914-4054-b144-0571efde09cc text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-624ac953-4914-4054-b144-0571efde09cc{background-color:rgba(249,249,249,1)}#chart-624ac953-4914-4054-b144-0571efde09cc path,#chart-624ac953-4914-4054-b144-0571efde09cc line,#chart-624ac953-4914-4054-b144-0571efde09cc rect,#chart-624ac953-4914-4054-b144-0571efde09cc circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-624ac953-4914-4054-b144-0571efde09cc .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .graph{fill:rgba(0,0,0,.87)}#chart-624ac953-4914-4054-b144-0571efde09cc text.no_data{fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .title{fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .legends .legend text{fill:rgba(0,0,0,.87)}#chart-624ac953-4914-4054-b144-0571efde09cc .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .axis .line{stroke:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-624ac953-4914-4054-b144-0571efde09cc .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-624ac953-4914-4054-b144-0571efde09cc .axis text.major{fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.y .guides:hover .guide.line,#chart-624ac953-4914-4054-b144-0571efde09cc .line-graph .axis.x .guides:hover .guide.line,#chart-624ac953-4914-4054-b144-0571efde09cc .stackedline-graph .axis.x .guides:hover .guide.line,#chart-624ac953-4914-4054-b144-0571efde09cc .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-624ac953-4914-4054-b144-0571efde09cc .ci{stroke:rgba(0,0,0,.87)}#chart-624ac953-4914-4054-b144-0571efde09cc .reactive.active,#chart-624ac953-4914-4054-b144-0571efde09cc .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-624ac953-4914-4054-b144-0571efde09cc .ci .reactive.active{stroke-width:1.5}#chart-624ac953-4914-4054-b144-0571efde09cc .series text{fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip .label{fill:rgba(0,0,0,.87)}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip .label{fill:rgba(0,0,0,.87)}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-624ac953-4914-4054-b144-0571efde09cc .tooltip .value{font-size:1.5em}#chart-624ac953-4914-4054-b144-0571efde09cc .bound{font-size:.5em}#chart-624ac953-4914-4054-b144-0571efde09cc .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-624ac953-4914-4054-b144-0571efde09cc .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-624ac953-4914-4054-b144-0571efde09cc .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-624ac953-4914-4054-b144-0571efde09cc .color-0,#chart-624ac953-4914-4054-b144-0571efde09cc .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-624ac953-4914-4054-b144-0571efde09cc .color-1,#chart-624ac953-4914-4054-b144-0571efde09cc .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-624ac953-4914-4054-b144-0571efde09cc .color-2,#chart-624ac953-4914-4054-b144-0571efde09cc .color-2 a:visited{stroke:#009688;fill:#009688}#chart-624ac953-4914-4054-b144-0571efde09cc .color-3,#chart-624ac953-4914-4054-b144-0571efde09cc .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-624ac953-4914-4054-b144-0571efde09cc .color-4,#chart-624ac953-4914-4054-b144-0571efde09cc .color-4 a:visit ...
# #chart-624ac953-4914-4054-b144-0571efde09cc text.no_data{text-anchor:middle}#chart-624ac953-4914-4054-b144-0571efde09cc .guide.line{fill:none}#chart-624ac953-4914-4054-b144-0571efde09cc .centered{text-anchor:middle}#chart-624ac953-4914-4054-b144-0571efde09cc .title{text-anchor:middle}#chart-624ac953-4914-4054-b144-0571efde09cc .legends .legend text{fill-opacity:1}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.x text{text-anchor:middle}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.x:not(.web) text[transform]{text-anchor:start}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.y text{text-anchor:end}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.y text[transform].backwards{text-anchor:start}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.y2 text{text-anchor:start}#chart-624ac953-4914-4054-b144-0571efde09cc .axis.y2 text[transform].backwards{text-anchor:end}#chart-624ac953-4914-4054-b144-0571efde09cc .axis .guide.line{stroke-dasharray:4,4}#chart-624ac953-4914-4054-b144-0571efde09cc .axis .major.guide.line{stroke-dasharray:6,6}#chart-624ac953-4914-4054-b144-0571efde09cc .horizontal .axis.y .guide.line,#chart-624ac953-4914-4054-b144-0571efde09cc .horizontal .axis.y2 .guide.line,#chart-624ac953-4914-4054-b144-0571efde09cc .vertical .axis.x .guide.line{opacity:0}#chart-624ac953-4914-4054-b144-0571efde09cc .horizontal .axis.always_show .guide.line,#chart-624ac953-4914-4054-b144-0571efde09cc .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-624ac953-4914-4054-b144-0571ef

# %%
from pygal.style import *

# %%
from pygal.style import Style
custom_style = Style(
  background='transparent',
  plot_background='transparent',
  font_family = 'googlefont:Bad Script',
  colors=('#05668D', '#028090', '#00A896', '#02C39A', '#F0F3BD'))
